# %% [markdown]
# ## Couple of examples for optimization of custom function with PyTorch

# %%
import torch
import torch.optim as optim

# %% [markdown]
# ### First of all try manually one cycle. We are going to find a minimum for function $y = x ^ 2$

# %%
initial_value = 100.
lr = 0.01
x_0 = torch.tensor([initial_value], requires_grad=True)

# %%
# Define optimizer: 
optimizer = optim.SGD([x_0], lr=lr, momentum=0.1)

# %%
# Don't forget to reset grads:
optimizer.zero_grad()

# %%
out = x_0 ** 2
out.backward()
out
# Out:
# tensor([10000.], grad_fn=<PowBackward0>)

# %% [markdown]
# Print the derivative:

# %%
x_0.grad
# Out:
# tensor([200.])

# %% [markdown]
# Make one step of Gradient Descent:

# %%
optimizer.step()

# %% [markdown]
# Print new value of x_0

# %%
x_0
# Out:
# tensor([98.], requires_grad=True)

# %% [markdown]
# Just check it manually:

# %%
manual_new_x_0 = initial_value - lr * x_0.grad.item() # where 100 is initial value , 0.
manual_new_x_0
# Out:
# 98.0

# %%
assert manual_new_x_0 == x_0

# %% [markdown]
# Now let's make several iterations:

# %%
for i in range(20):
  print('Iteration:', i + 1)
  optimizer.zero_grad()
  
  output = x_0 ** 2
  # loss = criterion(output, torch.tensor([0.]))
  
  output.backward()
  print('x_0 = ', round(x_0.item(), 3), '|', 'x_0_grad = ', round(x_0.grad.item(), 3))
  optimizer.step()
  
  print('out = ', round(output.item(), 3), '|', 'x_0 (after step) = ', round(x_0.item(), 3))
  print('------------------------------')
# Out:
# Iteration: 1
# x_0 =  62.466 | x_0_grad =  124.933
# out =  3902.045 | x_0 (after step) =  61.075
# ------------------------------
# Iteration: 2
# x_0 =  61.075 | x_0_grad =  122.149
# out =  3730.117 | x_0 (after step) =  59.714
# ------------------------------
# Iteration: 3
# x_0 =  59.714 | x_0_grad =  119.428
# out =  3565.765 | x_0 (after step) =  58.384
# ------------------------------
# Iteration: 4
# x_0 =  58.384 | x_0_grad =  116.767
# out =  3408.654 | x_0 (after step) =  57.083
# ------------------------------
# Iteration: 5
# x_0 =  57.083 | x_0_grad =  114.166
# out =  3258.465 | x_0 (after step) =  55.811
# ------------------------------
# Iteration: 6
# x_0 =  55.811 | x_0_grad =  111.622
# out =  3114.895 | x_0 (after step) =  54.568
# ------------------------------
# Iteration: 7
# x_0 =  54.568 | x_0_grad =  109.136
# out =  2977.65 | x_0 (after step) =  53.352
# ------------------------------
# Iteration: 8
# x_0 =  53.352 | x_0_grad =  106.704
# out =  2846.451 | x_0 (after step) =  52.164
# ------------------------------
# Iteration: 9
# x_0 =  52.164 | x_0_grad =  104.327
# out =  2721.034 | x_0 (after step) =  51.001
# ------------------------------
# Iteration: 10
# x_0 =  51.001 | x_0_grad =  102.003
# out =  2601.143 | x_0 (after step) =  49.865
# ------------------------------
# Iteration: 11
# x_0 =  49.865 | x_0_grad =  99.73
# out =  2486.534 | x_0 (after step) =  48.754
# ------------------------------
# Iteration: 12
# x_0 =  48.754 | x_0_grad =  97.508
# out =  2376.975 | x_0 (after step) =  47.668
# ------------------------------
# Iteration: 13
# x_0 =  47.668 | x_0_grad =  95.336
# out =  2272.243 | x_0 (after step) =  46.606
# ------------------------------
# Iteration: 14
# x_0 =  46.606 | x_0_grad =  93.212
# out =  2172.126 | x_0 (after step) =  45.568
# ------------------------------
# Iteration: 15
# x_0 =  45.568 | x_0_grad =  91.136
# out =  2076.42 | x_0 (after step) =  44.553
# ------------------------------
# Iteration: 16
# x_0 =  44.553 | x_0_grad =  89.105
# out =  1984.932 | x_0 (after step) =  43.56
# ------------------------------
# Iteration: 17
# x_0 =  43.56 | x_0_grad =  87.12
# out =  1897.474 | x_0 (after step) =  42.59
# ------------------------------
# Iteration: 18
# x_0 =  42.59 | x_0_grad =  85.179
# out =  1813.87 | x_0 (after step) =  41.641
# ------------------------------
# Iteration: 19
# x_0 =  41.641 | x_0_grad =  83.281
# out =  1733.949 | x_0 (after step) =  40.713
# ------------------------------
# Iteration: 20
# x_0 =  40.713 | x_0_grad =  81.426
# out =  1657.549 | x_0 (after step) =  39.806
# ------------------------------

# %% [markdown]
# ## Now another example but we will optimize this function:
# $f(x) = 2x^5-5x^4+x^3+3x^2-x$
#
# Here is the graph:
# https://www.desmos.com/calculator/i3rnu6mrsy

# %% [markdown]
# This function has 2 local minum at points approximately:
# $x_0=0.167$, $x_0=1.604$ and also $\lim \limits_{x \to -\infty}^{} f(x)= - \infty$

# %% [markdown]
# You can try several start points and different learning rates. Eventually you will reach one of those three points, i.e $x_0=0.167$, $x_0=1.604$ or $x_0 = - \infty$

# %%
initial_value = 4.
lr = 0.001

x_0 = torch.tensor([initial_value], requires_grad=True)
# Define loss function:
criterion = torch.nn.MSELoss()
# Define optimizer: 
optimizer = optim.SGD([x_0], lr=lr, momentum=0.0)

# %%
for i in range(200):
  print('Iteration:', i + 1)
  optimizer.zero_grad()
  
  output = 2 * x_0 ** 5 - 5 * x_0 ** 4 + x_0 ** 3 + 3 * x_0 ** 2 - x_0
  # loss = criterion(output, torch.tensor([0.]))
  
  output.backward()
  print('x_0 = ', round(x_0.item(), 3), '|', 'x_0_grad = ', round(x_0.grad.item(), 3))
  optimizer.step()
  
  print('out = ', round(output.item(), 3), '|', 'x_0 (after step) = ', round(x_0.item(), 3))
  print('------------------------------')
# Out:
# Iteration: 1
# x_0 =  4.0 | x_0_grad =  1351.0
# out =  876.0 | x_0 (after step) =  2.649
# ------------------------------
# Iteration: 2
# x_0 =  2.649 | x_0_grad =  156.585
# out =  51.665 | x_0 (after step) =  2.492
# ------------------------------
# Iteration: 3
# x_0 =  2.492 | x_0_grad =  108.832
# out =  31.042 | x_0 (after step) =  2.384
# ------------------------------
# Iteration: 4
# x_0 =  2.384 | x_0_grad =  82.291
# out =  20.687 | x_0 (after step) =  2.301
# ------------------------------
# Iteration: 5
# x_0 =  2.301 | x_0_grad =  65.415
# out =  14.628 | x_0 (after step) =  2.236
# ------------------------------
# Iteration: 6
# x_0 =  2.236 | x_0_grad =  53.778
# out =  10.737 | x_0 (after step) =  2.182
# ------------------------------
# Iteration: 7
# x_0 =  2.182 | x_0_grad =  45.298
# out =  8.078 | x_0 (after step) =  2.137
# ------------------------------
# Iteration: 8
# x_0 =  2.137 | x_0_grad =  38.865
# out =  6.174 | x_0 (after step) =  2.098
# ------------------------------
# Iteration: 9
# x_0 =  2.098 | x_0_grad =  33.835
# out =  4.762 | x_0 (after step) =  2.064
# ------------------------------
# Iteration: 10
# x_0 =  2.064 | x_0_grad =  29.803
# out =  3.687 | x_0 (after step) =  2.034
# ------------------------------
# Iteration: 11
# x_0 =  2.034 | x_0_grad =  26.508
# out =  2.848 | x_0 (after step) =  2.008
# ------------------------------
# Iteration: 12
# x_0 =  2.008 | x_0_grad =  23.771
# out =  2.182 | x_0 (after step) =  1.984
# ------------------------------
# Iteration: 13
# x_0 =  1.984 | x_0_grad =  21.465
# out =  1.645 | x_0 (after step) =  1.963
# ------------------------------
# Iteration: 14
# x_0 =  1.963 | x_0_grad =  19.5
# out =  1.205 | x_0 (after step) =  1.943
# ------------------------------
# Iteration: 15
# x_0 =  1.943 | x_0_grad =  17.807
# out =  0.842 | x_0 (after step) =  1.925
# ------------------------------
# Iteration: 16
# x_0 =  1.925 | x_0_grad =  16.337
# out =  0.538 | x_0 (after step) =  1.909
# ------------------------------
# Iteration: 17
# x_0 =  1.909 | x_0_grad =  15.049
# out =  0.282 | x_0 (after step) =  1.894
# ------------------------------
# Iteration: 18
# x_0 =  1.894 | x_0_grad =  13.914
# out =  0.064 | x_0 (after step) =  1.88
# ------------------------------
# Iteration: 19
# x_0 =  1.88 | x_0_grad =  12.906
# out =  -0.123 | x_0 (after step) =  1.867
# ------------------------------
# Iteration: 20
# x_0 =  1.867 | x_0_grad =  12.007
# out =  -0.284 | x_0 (after step) =  1.855
# ------------------------------
# Iteration: 21
# x_0 =  1.855 | x_0_grad =  11.2
# out =  -0.423 | x_0 (after step) =  1.844
# ------------------------------
# Iteration: 22
# x_0 =  1.844 | x_0_grad =  10.473
# out =  -0.544 | x_0 (after step) =  1.833
# ------------------------------
# Iteration: 23
# x_0 =  1.833 | x_0_grad =  9.815
# out =  -0.65 | x_0 (after step) =  1.824
# ------------------------------
# Iteration: 24
# x_0 =  1.824 | x_0_grad =  9.217
# out =  -0.744 | x_0 (after step) =  1.814
# ------------------------------
# Iteration: 25
# x_0 =  1.814 | x_0_grad =  8.672
# out =  -0.826 | x_0 (after step) =  1.806
# ------------------------------
# Iteration: 26
# x_0 =  1.806 | x_0_grad =  8.174
# out =  -0.899 | x_0 (after step) =  1.797
# ------------------------------
# Iteration: 27
# x_0 =  1.797 | x_0_grad =  7.716
# out =  -0.964 | x_0 (after step) =  1.79
# ------------------------------
# Iteration: 28
# x_0 =  1.79 | x_0_grad =  7.296
# out =  -1.022 | x_0 (after step) =  1.782
# ------------------------------
# Iteration: 29
# x_0 =  1.782 | x_0_grad =  6.907
# out =  -1.074 | x_0 (after step) =  1.776
# ------------------------------
# Iteration: 30
# x_0 =  1.776 | x_0_grad =  6.548
# out =  -1.12 | x_0 (after step) =  1.769
# ------------------------------
# Iteration: 31
# x_0 =  1.769 | x_0_grad =  6.215
# out =  -1.162 | x_0 (after step) =  1.763
# ------------------------------
# Iteration: 32
# x_0 =  1.763 | x_0_grad =  5.906
# out =  -1.2 | x_0 (after step) =  1.757
# ------------------------------
# Iteration: 33
# x_0 =  1.757 | x_0_grad =  5.618
# out =  -1.234 | x_0 (after step) =  1.751
# ------------------------------
# Iteration: 34
# x_0 =  1.751 | x_0_grad =  5.349
# out =  -1.265 | x_0 (after step) =  1.746
# ------------------------------
# Iteration: 35
# x_0 =  1.746 | x_0_grad =  5.099
# out =  -1.293 | x_0 (after step) =  1.741
# ------------------------------
# Iteration: 36
# x_0 =  1.741 | x_0_grad =  4.864
# out =  -1.318 | x_0 (after step) =  1.736
# ------------------------------
# Iteration: 37
# x_0 =  1.736 | x_0_grad =  4.644
# out =  -1.341 | x_0 (after step) =  1.731
# ------------------------------
# Iteration: 38
# x_0 =  1.731 | x_0_grad =  4.437
# out =  -1.362 | x_0 (after step) =  1.727
# ------------------------------
# Iteration: 39
# x_0 =  1.727 | x_0_grad =  4.243
# out =  -1.381 | x_0 (after step) =  1.723
# ------------------------------
# Iteration: 40
# x_0 =  1.723 | x_0_grad =  4.06
# out =  -1.399 | x_0 (after step) =  1.719
# ------------------------------
# Iteration: 41
# x_0 =  1.719 | x_0_grad =  3.888
# out =  -1.415 | x_0 (after step) =  1.715
# ------------------------------
# Iteration: 42
# x_0 =  1.715 | x_0_grad =  3.725
# out =  -1.43 | x_0 (after step) =  1.711
# ------------------------------
# Iteration: 43
# x_0 =  1.711 | x_0_grad =  3.571
# out =  -1.444 | x_0 (after step) =  1.707
# ------------------------------
# Iteration: 44
# x_0 =  1.707 | x_0_grad =  3.426
# out =  -1.456 | x_0 (after step) =  1.704
# ------------------------------
# Iteration: 45
# x_0 =  1.704 | x_0_grad =  3.288
# out =  -1.468 | x_0 (after step) =  1.701
# ------------------------------
# Iteration: 46
# x_0 =  1.701 | x_0_grad =  3.158
# out =  -1.478 | x_0 (after step) =  1.698
# ------------------------------
# Iteration: 47
# x_0 =  1.698 | x_0_grad =  3.034
# out =  -1.488 | x_0 (after step) =  1.694
# ------------------------------
# Iteration: 48
# x_0 =  1.694 | x_0_grad =  2.917
# out =  -1.497 | x_0 (after step) =  1.692
# ------------------------------
# Iteration: 49
# x_0 =  1.692 | x_0_grad =  2.805
# out =  -1.505 | x_0 (after step) =  1.689
# ------------------------------
# Iteration: 50
# x_0 =  1.689 | x_0_grad =  2.699
# out =  -1.513 | x_0 (after step) =  1.686
# ------------------------------
# Iteration: 51
# x_0 =  1.686 | x_0_grad =  2.598
# out =  -1.52 | x_0 (after step) =  1.683
# ------------------------------
# Iteration: 52
# x_0 =  1.683 | x_0_grad =  2.501
# out =  -1.527 | x_0 (after step) =  1.681
# ------------------------------
# Iteration: 53
# x_0 =  1.681 | x_0_grad =  2.409
# out =  -1.533 | x_0 (after step) =  1.679
# ------------------------------
# Iteration: 54
# x_0 =  1.679 | x_0_grad =  2.322
# out =  -1.539 | x_0 (after step) =  1.676
# ------------------------------
# Iteration: 55
# x_0 =  1.676 | x_0_grad =  2.238
# out =  -1.544 | x_0 (after step) =  1.674
# ------------------------------
# Iteration: 56
# x_0 =  1.674 | x_0_grad =  2.158
# out =  -1.549 | x_0 (after step) =  1.672
# ------------------------------
# Iteration: 57
# x_0 =  1.672 | x_0_grad =  2.082
# out =  -1.553 | x_0 (after step) =  1.67
# ------------------------------
# Iteration: 58
# x_0 =  1.67 | x_0_grad =  2.009
# out =  -1.558 | x_0 (after step) =  1.668
# ------------------------------
# Iteration: 59
# x_0 =  1.668 | x_0_grad =  1.939
# out =  -1.562 | x_0 (after step) =  1.666
# ------------------------------
# Iteration: 60
# x_0 =  1.666 | x_0_grad =  1.872
# out =  -1.565 | x_0 (after step) =  1.664
# ------------------------------
# Iteration: 61
# x_0 =  1.664 | x_0_grad =  1.808
# out =  -1.569 | x_0 (after step) =  1.662
# ------------------------------
# Iteration: 62
# x_0 =  1.662 | x_0_grad =  1.746
# out =  -1.572 | x_0 (after step) =  1.66
# ------------------------------
# Iteration: 63
# x_0 =  1.66 | x_0_grad =  1.687
# out =  -1.575 | x_0 (after step) =  1.659
# ------------------------------
# Iteration: 64
# x_0 =  1.659 | x_0_grad =  1.631
# out =  -1.578 | x_0 (after step) =  1.657
# ------------------------------
# Iteration: 65
# x_0 =  1.657 | x_0_grad =  1.576
# out =  -1.58 | x_0 (after step) =  1.655
# ------------------------------
# Iteration: 66
# x_0 =  1.655 | x_0_grad =  1.524
# out =  -1.583 | x_0 (after step) =  1.654
# ------------------------------
# Iteration: 67
# x_0 =  1.654 | x_0_grad =  1.474
# out =  -1.585 | x_0 (after step) =  1.652
# ------------------------------
# Iteration: 68
# x_0 =  1.652 | x_0_grad =  1.426
# out =  -1.587 | x_0 (after step) =  1.651
# ------------------------------
# Iteration: 69
# x_0 =  1.651 | x_0_grad =  1.38
# out =  -1.589 | x_0 (after step) =  1.65
# ------------------------------
# Iteration: 70
# x_0 =  1.65 | x_0_grad =  1.335
# out =  -1.591 | x_0 (after step) =  1.648
# ------------------------------
# Iteration: 71
# x_0 =  1.648 | x_0_grad =  1.292
# out =  -1.593 | x_0 (after step) =  1.647
# ------------------------------
# Iteration: 72
# x_0 =  1.647 | x_0_grad =  1.251
# out =  -1.595 | x_0 (after step) =  1.646
# ------------------------------
# Iteration: 73
# x_0 =  1.646 | x_0_grad =  1.211
# out =  -1.596 | x_0 (after step) =  1.645
# ------------------------------
# Iteration: 74
# x_0 =  1.645 | x_0_grad =  1.173
# out =  -1.598 | x_0 (after step) =  1.643
# ------------------------------
# Iteration: 75
# x_0 =  1.643 | x_0_grad =  1.136
# out =  -1.599 | x_0 (after step) =  1.642
# ------------------------------
# Iteration: 76
# x_0 =  1.642 | x_0_grad =  1.101
# out =  -1.6 | x_0 (after step) =  1.641
# ------------------------------
# Iteration: 77
# x_0 =  1.641 | x_0_grad =  1.066
# out =  -1.601 | x_0 (after step) =  1.64
# ------------------------------
# Iteration: 78
# x_0 =  1.64 | x_0_grad =  1.033
# out =  -1.603 | x_0 (after step) =  1.639
# ------------------------------
# Iteration: 79
# x_0 =  1.639 | x_0_grad =  1.001
# out =  -1.604 | x_0 (after step) =  1.638
# ------------------------------
# Iteration: 80
# x_0 =  1.638 | x_0_grad =  0.971
# out =  -1.605 | x_0 (after step) =  1.637
# ------------------------------
# Iteration: 81
# x_0 =  1.637 | x_0_grad =  0.941
# out =  -1.605 | x_0 (after step) =  1.636
# ------------------------------
# Iteration: 82
# x_0 =  1.636 | x_0_grad =  0.912
# out =  -1.606 | x_0 (after step) =  1.635
# ------------------------------
# Iteration: 83
# x_0 =  1.635 | x_0_grad =  0.885
# out =  -1.607 | x_0 (after step) =  1.634
# ------------------------------
# Iteration: 84
# x_0 =  1.634 | x_0_grad =  0.858
# out =  -1.608 | x_0 (after step) =  1.634
# ------------------------------
# Iteration: 85
# x_0 =  1.634 | x_0_grad =  0.832
# out =  -1.609 | x_0 (after step) =  1.633
# ------------------------------
# Iteration: 86
# x_0 =  1.633 | x_0_grad =  0.807
# out =  -1.609 | x_0 (after step) =  1.632
# ------------------------------
# Iteration: 87
# x_0 =  1.632 | x_0_grad =  0.783
# out =  -1.61 | x_0 (after step) =  1.631
# ------------------------------
# Iteration: 88
# x_0 =  1.631 | x_0_grad =  0.76
# out =  -1.611 | x_0 (after step) =  1.63
# ------------------------------
# Iteration: 89
# x_0 =  1.63 | x_0_grad =  0.737
# out =  -1.611 | x_0 (after step) =  1.63
# ------------------------------
# Iteration: 90
# x_0 =  1.63 | x_0_grad =  0.715
# out =  -1.612 | x_0 (after step) =  1.629
# ------------------------------
# Iteration: 91
# x_0 =  1.629 | x_0_grad =  0.694
# out =  -1.612 | x_0 (after step) =  1.628
# ------------------------------
# Iteration: 92
# x_0 =  1.628 | x_0_grad =  0.674
# out =  -1.613 | x_0 (after step) =  1.628
# ------------------------------
# Iteration: 93
# x_0 =  1.628 | x_0_grad =  0.654
# out =  -1.613 | x_0 (after step) =  1.627
# ------------------------------
# Iteration: 94
# x_0 =  1.627 | x_0_grad =  0.635
# out =  -1.614 | x_0 (after step) =  1.626
# ------------------------------
# Iteration: 95
# x_0 =  1.626 | x_0_grad =  0.616
# out =  -1.614 | x_0 (after step) =  1.626
# ------------------------------
# Iteration: 96
# x_0 =  1.626 | x_0_grad =  0.598
# out =  -1.614 | x_0 (after step) =  1.625
# ------------------------------
# Iteration: 97
# x_0 =  1.625 | x_0_grad =  0.581
# out =  -1.615 | x_0 (after step) =  1.624
# ------------------------------
# Iteration: 98
# x_0 =  1.624 | x_0_grad =  0.564
# out =  -1.615 | x_0 (after step) =  1.624
# ------------------------------
# Iteration: 99
# x_0 =  1.624 | x_0_grad =  0.548
# out =  -1.615 | x_0 (after step) =  1.623
# ------------------------------
# Iteration: 100
# x_0 =  1.623 | x_0_grad =  0.532
# out =  -1.616 | x_0 (after step) =  1.623
# ------------------------------
# Iteration: 101
# x_0 =  1.623 | x_0_grad =  0.517
# out =  -1.616 | x_0 (after step) =  1.622
# ------------------------------
# Iteration: 102
# x_0 =  1.622 | x_0_grad =  0.502
# out =  -1.616 | x_0 (after step) =  1.622
# ------------------------------
# Iteration: 103
# x_0 =  1.622 | x_0_grad =  0.488
# out =  -1.616 | x_0 (after step) =  1.621
# ------------------------------
# Iteration: 104
# x_0 =  1.621 | x_0_grad =  0.474
# out =  -1.617 | x_0 (after step) =  1.621
# ------------------------------
# Iteration: 105
# x_0 =  1.621 | x_0_grad =  0.46
# out =  -1.617 | x_0 (after step) =  1.62
# ------------------------------
# Iteration: 106
# x_0 =  1.62 | x_0_grad =  0.447
# out =  -1.617 | x_0 (after step) =  1.62
# ------------------------------
# Iteration: 107
# x_0 =  1.62 | x_0_grad =  0.435
# out =  -1.617 | x_0 (after step) =  1.619
# ------------------------------
# Iteration: 108
# x_0 =  1.619 | x_0_grad =  0.422
# out =  -1.617 | x_0 (after step) =  1.619
# ------------------------------
# Iteration: 109
# x_0 =  1.619 | x_0_grad =  0.41
# out =  -1.618 | x_0 (after step) =  1.619
# ------------------------------
# Iteration: 110
# x_0 =  1.619 | x_0_grad =  0.399
# out =  -1.618 | x_0 (after step) =  1.618
# ------------------------------
# Iteration: 111
# x_0 =  1.618 | x_0_grad =  0.388
# out =  -1.618 | x_0 (after step) =  1.618
# ------------------------------
# Iteration: 112
# x_0 =  1.618 | x_0_grad =  0.377
# out =  -1.618 | x_0 (after step) =  1.617
# ------------------------------
# Iteration: 113
# x_0 =  1.617 | x_0_grad =  0.366
# out =  -1.618 | x_0 (after step) =  1.617
# ------------------------------
# Iteration: 114
# x_0 =  1.617 | x_0_grad =  0.356
# out =  -1.618 | x_0 (after step) =  1.617
# ------------------------------
# Iteration: 115
# x_0 =  1.617 | x_0_grad =  0.346
# out =  -1.618 | x_0 (after step) =  1.616
# ------------------------------
# Iteration: 116
# x_0 =  1.616 | x_0_grad =  0.336
# out =  -1.619 | x_0 (after step) =  1.616
# ------------------------------
# Iteration: 117
# x_0 =  1.616 | x_0_grad =  0.327
# out =  -1.619 | x_0 (after step) =  1.616
# ------------------------------
# Iteration: 118
# x_0 =  1.616 | x_0_grad =  0.318
# out =  -1.619 | x_0 (after step) =  1.615
# ------------------------------
# Iteration: 119
# x_0 =  1.615 | x_0_grad =  0.309
# out =  -1.619 | x_0 (after step) =  1.615
# ------------------------------
# Iteration: 120
# x_0 =  1.615 | x_0_grad =  0.301
# out =  -1.619 | x_0 (after step) =  1.615
# ------------------------------
# Iteration: 121
# x_0 =  1.615 | x_0_grad =  0.292
# out =  -1.619 | x_0 (after step) =  1.615
# ------------------------------
# Iteration: 122
# x_0 =  1.615 | x_0_grad =  0.284
# out =  -1.619 | x_0 (after step) =  1.614
# ------------------------------
# Iteration: 123
# x_0 =  1.614 | x_0_grad =  0.276
# out =  -1.619 | x_0 (after step) =  1.614
# ------------------------------
# Iteration: 124
# x_0 =  1.614 | x_0_grad =  0.269
# out =  -1.619 | x_0 (after step) =  1.614
# ------------------------------
# Iteration: 125
# x_0 =  1.614 | x_0_grad =  0.261
# out =  -1.619 | x_0 (after step) =  1.613
# ------------------------------
# Iteration: 126
# x_0 =  1.613 | x_0_grad =  0.254
# out =  -1.619 | x_0 (after step) =  1.613
# ------------------------------
# Iteration: 127
# x_0 =  1.613 | x_0_grad =  0.247
# out =  -1.62 | x_0 (after step) =  1.613
# ------------------------------
# Iteration: 128
# x_0 =  1.613 | x_0_grad =  0.24
# out =  -1.62 | x_0 (after step) =  1.613
# ------------------------------
# Iteration: 129
# x_0 =  1.613 | x_0_grad =  0.234
# out =  -1.62 | x_0 (after step) =  1.612
# ------------------------------
# Iteration: 130
# x_0 =  1.612 | x_0_grad =  0.227
# out =  -1.62 | x_0 (after step) =  1.612
# ------------------------------
# Iteration: 131
# x_0 =  1.612 | x_0_grad =  0.221
# out =  -1.62 | x_0 (after step) =  1.612
# ------------------------------
# Iteration: 132
# x_0 =  1.612 | x_0_grad =  0.215
# out =  -1.62 | x_0 (after step) =  1.612
# ------------------------------
# Iteration: 133
# x_0 =  1.612 | x_0_grad =  0.209
# out =  -1.62 | x_0 (after step) =  1.612
# ------------------------------
# Iteration: 134
# x_0 =  1.612 | x_0_grad =  0.204
# out =  -1.62 | x_0 (after step) =  1.611
# ------------------------------
# Iteration: 135
# x_0 =  1.611 | x_0_grad =  0.198
# out =  -1.62 | x_0 (after step) =  1.611
# ------------------------------
# Iteration: 136
# x_0 =  1.611 | x_0_grad =  0.193
# out =  -1.62 | x_0 (after step) =  1.611
# ------------------------------
# Iteration: 137
# x_0 =  1.611 | x_0_grad =  0.187
# out =  -1.62 | x_0 (after step) =  1.611
# ------------------------------
# Iteration: 138
# x_0 =  1.611 | x_0_grad =  0.182
# out =  -1.62 | x_0 (after step) =  1.611
# ------------------------------
# Iteration: 139
# x_0 =  1.611 | x_0_grad =  0.177
# out =  -1.62 | x_0 (after step) =  1.61
# ------------------------------
# Iteration: 140
# x_0 =  1.61 | x_0_grad =  0.172
# out =  -1.62 | x_0 (after step) =  1.61
# ------------------------------
# Iteration: 141
# x_0 =  1.61 | x_0_grad =  0.168
# out =  -1.62 | x_0 (after step) =  1.61
# ------------------------------
# Iteration: 142
# x_0 =  1.61 | x_0_grad =  0.163
# out =  -1.62 | x_0 (after step) =  1.61
# ------------------------------
# Iteration: 143
# x_0 =  1.61 | x_0_grad =  0.159
# out =  -1.62 | x_0 (after step) =  1.61
# ------------------------------
# Iteration: 144
# x_0 =  1.61 | x_0_grad =  0.155
# out =  -1.62 | x_0 (after step) =  1.61
# ------------------------------
# Iteration: 145
# x_0 =  1.61 | x_0_grad =  0.15
# out =  -1.62 | x_0 (after step) =  1.609
# ------------------------------
# Iteration: 146
# x_0 =  1.609 | x_0_grad =  0.146
# out =  -1.62 | x_0 (after step) =  1.609
# ------------------------------
# Iteration: 147
# x_0 =  1.609 | x_0_grad =  0.142
# out =  -1.62 | x_0 (after step) =  1.609
# ------------------------------
# Iteration: 148
# x_0 =  1.609 | x_0_grad =  0.139
# out =  -1.62 | x_0 (after step) =  1.609
# ------------------------------
# Iteration: 149
# x_0 =  1.609 | x_0_grad =  0.135
# out =  -1.62 | x_0 (after step) =  1.609
# ------------------------------
# Iteration: 150
# x_0 =  1.609 | x_0_grad =  0.131
# out =  -1.62 | x_0 (after step) =  1.609
# ------------------------------
# Iteration: 151
# x_0 =  1.609 | x_0_grad =  0.128
# out =  -1.62 | x_0 (after step) =  1.609
# ------------------------------
# Iteration: 152
# x_0 =  1.609 | x_0_grad =  0.124
# out =  -1.62 | x_0 (after step) =  1.609
# ------------------------------
# Iteration: 153
# x_0 =  1.609 | x_0_grad =  0.121
# out =  -1.62 | x_0 (after step) =  1.608
# ------------------------------
# Iteration: 154
# x_0 =  1.608 | x_0_grad =  0.118
# out =  -1.62 | x_0 (after step) =  1.608
# ------------------------------
# Iteration: 155
# x_0 =  1.608 | x_0_grad =  0.114
# out =  -1.62 | x_0 (after step) =  1.608
# ------------------------------
# Iteration: 156
# x_0 =  1.608 | x_0_grad =  0.111
# out =  -1.62 | x_0 (after step) =  1.608
# ------------------------------
# Iteration: 157
# x_0 =  1.608 | x_0_grad =  0.108
# out =  -1.62 | x_0 (after step) =  1.608
# ------------------------------
# Iteration: 158
# x_0 =  1.608 | x_0_grad =  0.105
# out =  -1.62 | x_0 (after step) =  1.608
# ------------------------------
# Iteration: 159
# x_0 =  1.608 | x_0_grad =  0.103
# out =  -1.62 | x_0 (after step) =  1.608
# ------------------------------
# Iteration: 160
# x_0 =  1.608 | x_0_grad =  0.1
# out =  -1.621 | x_0 (after step) =  1.608
# ------------------------------
# Iteration: 161
# x_0 =  1.608 | x_0_grad =  0.097
# out =  -1.621 | x_0 (after step) =  1.608
# ------------------------------
# Iteration: 162
# x_0 =  1.608 | x_0_grad =  0.095
# out =  -1.621 | x_0 (after step) =  1.607
# ------------------------------
# Iteration: 163
# x_0 =  1.607 | x_0_grad =  0.092
# out =  -1.621 | x_0 (after step) =  1.607
# ------------------------------
# Iteration: 164
# x_0 =  1.607 | x_0_grad =  0.09
# out =  -1.621 | x_0 (after step) =  1.607
# ------------------------------
# Iteration: 165
# x_0 =  1.607 | x_0_grad =  0.087
# out =  -1.621 | x_0 (after step) =  1.607
# ------------------------------
# Iteration: 166
# x_0 =  1.607 | x_0_grad =  0.085
# out =  -1.621 | x_0 (after step) =  1.607
# ------------------------------
# Iteration: 167
# x_0 =  1.607 | x_0_grad =  0.083
# out =  -1.621 | x_0 (after step) =  1.607
# ------------------------------
# Iteration: 168
# x_0 =  1.607 | x_0_grad =  0.08
# out =  -1.621 | x_0 (after step) =  1.607
# ------------------------------
# Iteration: 169
# x_0 =  1.607 | x_0_grad =  0.078
# out =  -1.621 | x_0 (after step) =  1.607
# ------------------------------
# Iteration: 170
# x_0 =  1.607 | x_0_grad =  0.076
# out =  -1.621 | x_0 (after step) =  1.607
# ------------------------------
# Iteration: 171
# x_0 =  1.607 | x_0_grad =  0.074
# out =  -1.621 | x_0 (after step) =  1.607
# ------------------------------
# Iteration: 172
# x_0 =  1.607 | x_0_grad =  0.072
# out =  -1.621 | x_0 (after step) =  1.607
# ------------------------------
# Iteration: 173
# x_0 =  1.607 | x_0_grad =  0.07
# out =  -1.621 | x_0 (after step) =  1.607
# ------------------------------
# Iteration: 174
# x_0 =  1.607 | x_0_grad =  0.068
# out =  -1.621 | x_0 (after step) =  1.607
# ------------------------------
# Iteration: 175
# x_0 =  1.607 | x_0_grad =  0.067
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 176
# x_0 =  1.606 | x_0_grad =  0.065
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 177
# x_0 =  1.606 | x_0_grad =  0.063
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 178
# x_0 =  1.606 | x_0_grad =  0.061
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 179
# x_0 =  1.606 | x_0_grad =  0.06
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 180
# x_0 =  1.606 | x_0_grad =  0.058
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 181
# x_0 =  1.606 | x_0_grad =  0.057
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 182
# x_0 =  1.606 | x_0_grad =  0.055
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 183
# x_0 =  1.606 | x_0_grad =  0.054
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 184
# x_0 =  1.606 | x_0_grad =  0.052
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 185
# x_0 =  1.606 | x_0_grad =  0.051
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 186
# x_0 =  1.606 | x_0_grad =  0.049
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 187
# x_0 =  1.606 | x_0_grad =  0.048
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 188
# x_0 =  1.606 | x_0_grad =  0.047
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 189
# x_0 =  1.606 | x_0_grad =  0.046
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 190
# x_0 =  1.606 | x_0_grad =  0.044
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 191
# x_0 =  1.606 | x_0_grad =  0.043
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 192
# x_0 =  1.606 | x_0_grad =  0.042
# out =  -1.621 | x_0 (after step) =  1.606
# ------------------------------
# Iteration: 193
# x_0 =  1.606 | x_0_grad =  0.041
# out =  -1.621 | x_0 (after step) =  1.605
# ------------------------------
# Iteration: 194
# x_0 =  1.605 | x_0_grad =  0.04
# out =  -1.621 | x_0 (after step) =  1.605
# ------------------------------
# Iteration: 195
# x_0 =  1.605 | x_0_grad =  0.039
# out =  -1.621 | x_0 (after step) =  1.605
# ------------------------------
# Iteration: 196
# x_0 =  1.605 | x_0_grad =  0.038
# out =  -1.621 | x_0 (after step) =  1.605
# ------------------------------
# Iteration: 197
# x_0 =  1.605 | x_0_grad =  0.037
# out =  -1.621 | x_0 (after step) =  1.605
# ------------------------------
# Iteration: 198
# x_0 =  1.605 | x_0_grad =  0.036
# out =  -1.621 | x_0 (after step) =  1.605
# ------------------------------
# Iteration: 199
# x_0 =  1.605 | x_0_grad =  0.035
# out =  -1.621 | x_0 (after step) =  1.605
# ------------------------------
# Iteration: 200
# x_0 =  1.605 | x_0_grad =  0.034
# out =  -1.621 | x_0 (after step) =  1.605
# ------------------------------

# %% [markdown]
# Notice that not always you will reach the closest minimum.
# For example, take initial_value = 4., lr = 0.1
#
# The closest minimum is obviously $x_0=1.604$
# However, at first iteration you will achive that:
# $x_{new} = x_0 - lr \cdot f'(x_0) = 4 - 0.01 \cdot 1351.0 = -9.51$
# And after it you will reach $-\infty$
